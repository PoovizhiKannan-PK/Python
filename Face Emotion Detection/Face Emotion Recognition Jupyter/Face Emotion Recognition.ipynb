# %%
import cv2
import numpy as np
import pandas as pd

# %%
img = cv2.imread('happy-boy.jpg')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img)  # By default its BGR

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
from deepface import DeepFace

# %%
predictions = DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:02<00:00,  1.54it/s]

# %%
predictions
# Out:
# {'emotion': {'angry': 5.922424588700016e-16,
#   'disgust': 5.292526938865555e-32,
#   'fear': 2.44294765822889e-17,
#   'happy': 99.99998807907104,
#   'sad': 2.0271215261935538e-10,
#   'surprise': 9.24038678906669e-08,
#   'neutral': 1.3139164423137117e-05},
#  'dominant_emotion': 'happy',
#  'region': {'x': 94, 'y': 33, 'w': 128, 'h': 128},
#  'age': 22,
#  'gender': 'Man',
#  'race': {'asian': 95.63242845148702,
#   'indian': 0.41690156481843416,
#   'black': 0.00915119198956287,
#   'white': 0.572947251296371,
#   'middle eastern': 0.007479770119618089,
#   'latino hispanic': 3.3610902445208737},
#  'dominant_race': 'asian'}

# %%
predictions['dominant_emotion']
# Out:
# 'happy'

# %%
# To draw rectangle across face

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(grey, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            predictions['dominant_emotion'],
           (0,50),
            font, 1,
            (0, 255, 0),
             2,
            cv2.LINE_4)
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
img = cv2.imread('sad-girl.jpg')
predictions = DeepFace.analyze(img)

grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(grey, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            predictions['dominant_emotion'],
           (50,100),
            font, 5,
            (0, 255, 0),
             10,
            cv2.LINE_4)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:01<00:00,  2.83it/s]

# %%
img = cv2.imread('surprised.jpg')
predictions = DeepFace.analyze(img)

grey = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

faces = faceCascade.detectMultiScale(grey, 1.1, 4)

for (x, y, w, h) in faces:
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

font = cv2.FONT_HERSHEY_SIMPLEX

cv2.putText(img,
            predictions['dominant_emotion'],
           (50,100),
            font, 5,
            (0, 255, 0),
             10,
            cv2.LINE_4)

plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:00<00:00,  4.20it/s]
